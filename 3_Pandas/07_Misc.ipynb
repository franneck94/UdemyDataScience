# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # IO Operations and Useful Methods
#
# | Format Type | Data Description | Reader         | Writer       |
# | ----------- | ---------------- | -------------- | ------------ |
# | text        | CSV              | read_csv       | to_csv       |
# | text        | JSON             | read_json      | to_json      |
# | text        | HTML             | read_html      | to_html      |
# | text        | Local clipboard  | read_clipboard | to_clipboard |
# | binary      | MS Excel         | read_excel     | to_excel     |
# | binary      | HDF5 Format      | read_hdf       | to_hdf       |
# | SQL         | SQL              | read_sql       | to_sql       |

# %%
np.random.seed(0)

# %%
def df_info(df: pd.DataFrame) -> None:
    return df.head(n=20).style

# %% [markdown]
# ## IO Operations

# %% [markdown]
# ### Titanic Dataset
#
# -   PassengerId is the unique id of the row and it doesn't have any effect on target
# -   Survived is the target variable we are trying to predict (0 or 1):
#     -   1 = Survived
#     -   0 = Not Survived
# -   Pclass (Passenger Class) is the socio-economic status of the passenger:
#     -   1 = Upper Class
#     -   2 = Middle Class
#     -   3 = Lower Class
# -   Name
# -   Sex
# -   Age
# -   SibSp is the total number of the passengers' siblings and spouse
# -   Parch is the total number of the passengers' parents and children
# -   Ticket is the ticket number of the passenger
# -   Fare is the passenger fare
# -   Cabin is the cabin number of the passenger
# -   Embarked is port of embarkation and it is a categorical feature:
#     -   C = Cherbourg
#     -   Q = Queenstown
#     -   S = Southampton
#
# \*Embarked: sich einschiffen

# %%
df = pd.read_csv("../data/titanic/dataset.csv")
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
cols = [
    "Survived",
    "Pclass",
    "Sex",
    "Age",
    "SibSp",
    "Parch",
    "Fare",
    "Cabin",
    "Embarked",
]

index_name = "PassengerId"

# %%
df = pd.DataFrame(
    df[cols],
    index=df[index_name],
)


df.index.name = "ID"

# %%
df_info(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0ef8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0ef8_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_d0ef8_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_d0ef8_level0_col2" class="col_heading level0 col2" >Sex</th>
#       <th id="T_d0ef8_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_d0ef8_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_d0ef8_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_d0ef8_level0_col6" class="col_heading level0 col6" >Fare</th>
#       <th id="T_d0ef8_level0_col7" class="col_heading level0 col7" >Cabin</th>
#       <th id="T_d0ef8_level0_col8" class="col_heading level0 col8" >Embarked</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0ef8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d0ef8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d0ef8_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d0ef8_row0_col2" class="data row0 col2" >female</td>
#       <td id="T_d0ef8_row0_col3" class="data row0 col3" >38.000000</td>
#       <td id="T_d0ef8_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_d0ef8_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_d0ef8_row0_col6" class="data row0 col6" >71.283300</td>
#       <td id="T_d0ef8_row0_col7" class="data row0 col7" >C85</td>
#       <td id="T_d0ef8_row0_col8" class="data row0 col8" >C</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d0ef8_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_d0ef8_row1_col1" class="data row1 col1" >3.000000</td>
#       <td id="T_d0ef8_row1_col2" class="data row1 col2" >female</td>
#       <td id="T_d0ef8_row1_col3" class="data row1 col3" >26.000000</td>
#       <td id="T_d0ef8_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_d0ef8_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_d0ef8_row1_col6" class="data row1 col6" >7.925000</td>
#       <td id="T_d0ef8_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_d0ef8_row1_col8" class="data row1 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d0ef8_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_d0ef8_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_d0ef8_row2_col2" class="data row2 col2" >female</td>
#       <td id="T_d0ef8_row2_col3" class="data row2 col3" >35.000000</td>
#       <td id="T_d0ef8_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_d0ef8_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_d0ef8_row2_col6" class="data row2 col6" >53.100000</td>
#       <td id="T_d0ef8_row2_col7" class="data row2 col7" >C123</td>
#       <td id="T_d0ef8_row2_col8" class="data row2 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d0ef8_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_d0ef8_row3_col1" class="data row3 col1" >3.000000</td>
#       <td id="T_d0ef8_row3_col2" class="data row3 col2" >male</td>
#       <td id="T_d0ef8_row3_col3" class="data row3 col3" >35.000000</td>
#       <td id="T_d0ef8_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_d0ef8_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_d0ef8_row3_col6" class="data row3 col6" >8.050000</td>
#       <td id="T_d0ef8_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_d0ef8_row3_col8" class="data row3 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d0ef8_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_d0ef8_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_d0ef8_row4_col2" class="data row4 col2" >male</td>
#       <td id="T_d0ef8_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d0ef8_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_d0ef8_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_d0ef8_row4_col6" class="data row4 col6" >8.458300</td>
#       <td id="T_d0ef8_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_d0ef8_row4_col8" class="data row4 col8" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d0ef8_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_d0ef8_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_d0ef8_row5_col2" class="data row5 col2" >male</td>
#       <td id="T_d0ef8_row5_col3" class="data row5 col3" >54.000000</td>
#       <td id="T_d0ef8_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_d0ef8_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_d0ef8_row5_col6" class="data row5 col6" >51.862500</td>
#       <td id="T_d0ef8_row5_col7" class="data row5 col7" >E46</td>
#       <td id="T_d0ef8_row5_col8" class="data row5 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d0ef8_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_d0ef8_row6_col1" class="data row6 col1" >3.000000</td>
#       <td id="T_d0ef8_row6_col2" class="data row6 col2" >male</td>
#       <td id="T_d0ef8_row6_col3" class="data row6 col3" >2.000000</td>
#       <td id="T_d0ef8_row6_col4" class="data row6 col4" >3.000000</td>
#       <td id="T_d0ef8_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_d0ef8_row6_col6" class="data row6 col6" >21.075000</td>
#       <td id="T_d0ef8_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_d0ef8_row6_col8" class="data row6 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d0ef8_row7_col0" class="data row7 col0" >1.000000</td>
#       <td id="T_d0ef8_row7_col1" class="data row7 col1" >3.000000</td>
#       <td id="T_d0ef8_row7_col2" class="data row7 col2" >female</td>
#       <td id="T_d0ef8_row7_col3" class="data row7 col3" >27.000000</td>
#       <td id="T_d0ef8_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_d0ef8_row7_col5" class="data row7 col5" >2.000000</td>
#       <td id="T_d0ef8_row7_col6" class="data row7 col6" >11.133300</td>
#       <td id="T_d0ef8_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_d0ef8_row7_col8" class="data row7 col8" >S</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d0ef8_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_d0ef8_row8_col1" class="data row8 col1" >2.000000</td>
#       <td id="T_d0ef8_row8_col2" class="data row8 col2" >female</td>
#       <td id="T_d0ef8_row8_col3" class="data row8 col3" >14.000000</td>
#       <td id="T_d0ef8_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_d0ef8_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_d0ef8_row8_col6" class="data row8 col6" >30.070800</td>
#       <td id="T_d0ef8_row8_col7" class="data row8 col7" >nan</td>
#       <td id="T_d0ef8_row8_col8" class="data row8 col8" >C</td>
#     </tr>
#     <tr>
#       <th id="T_d0ef8_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d0ef8_row9_col0" class="data row9 col0" >1.000000</td>
#       <td id="T_d0ef8_row9_col1" class="data row9 col1" >3.000000</td

# %%
df.iloc[:100].to_csv("../data/titanic/modified_dataset.csv")

# %%
df = pd.read_csv("../data/titanic/modified_dataset.csv")
df_info(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_55c9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55c9b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_55c9b_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_55c9b_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_55c9b_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_55c9b_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_55c9b_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_55c9b_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_55c9b_level0_col7" class="col_heading level0 col7" >Fare</th>
#       <th id="T_55c9b_level0_col8" class="col_heading level0 col8" >Cabin</th>
#       <th id="T_55c9b_level0_col9" class="col_heading level0 col9" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55c9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55c9b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_55c9b_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_55c9b_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_55c9b_row0_col3" class="data row0 col3" >female</td>
#       <td id="T_55c9b_row0_col4" class="data row0 col4" >38.000000</td>
#       <td id="T_55c9b_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_55c9b_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_55c9b_row0_col7" class="data row0 col7" >71.283300</td>
#       <td id="T_55c9b_row0_col8" class="data row0 col8" >C85</td>
#       <td id="T_55c9b_row0_col9" class="data row0 col9" >C</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55c9b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_55c9b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_55c9b_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_55c9b_row1_col3" class="data row1 col3" >female</td>
#       <td id="T_55c9b_row1_col4" class="data row1 col4" >26.000000</td>
#       <td id="T_55c9b_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_55c9b_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_55c9b_row1_col7" class="data row1 col7" >7.925000</td>
#       <td id="T_55c9b_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_55c9b_row1_col9" class="data row1 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55c9b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_55c9b_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_55c9b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_55c9b_row2_col3" class="data row2 col3" >female</td>
#       <td id="T_55c9b_row2_col4" class="data row2 col4" >35.000000</td>
#       <td id="T_55c9b_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_55c9b_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_55c9b_row2_col7" class="data row2 col7" >53.100000</td>
#       <td id="T_55c9b_row2_col8" class="data row2 col8" >C123</td>
#       <td id="T_55c9b_row2_col9" class="data row2 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55c9b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_55c9b_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_55c9b_row3_col2" class="data row3 col2" >3.000000</td>
#       <td id="T_55c9b_row3_col3" class="data row3 col3" >male</td>
#       <td id="T_55c9b_row3_col4" class="data row3 col4" >35.000000</td>
#       <td id="T_55c9b_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_55c9b_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_55c9b_row3_col7" class="data row3 col7" >8.050000</td>
#       <td id="T_55c9b_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_55c9b_row3_col9" class="data row3 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55c9b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_55c9b_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_55c9b_row4_col2" class="data row4 col2" >3.000000</td>
#       <td id="T_55c9b_row4_col3" class="data row4 col3" >male</td>
#       <td id="T_55c9b_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_55c9b_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_55c9b_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_55c9b_row4_col7" class="data row4 col7" >8.458300</td>
#       <td id="T_55c9b_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_55c9b_row4_col9" class="data row4 col9" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55c9b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_55c9b_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_55c9b_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_55c9b_row5_col3" class="data row5 col3" >male</td>
#       <td id="T_55c9b_row5_col4" class="data row5 col4" >54.000000</td>
#       <td id="T_55c9b_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_55c9b_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_55c9b_row5_col7" class="data row5 col7" >51.862500</td>
#       <td id="T_55c9b_row5_col8" class="data row5 col8" >E46</td>
#       <td id="T_55c9b_row5_col9" class="data row5 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55c9b_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_55c9b_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_55c9b_row6_col2" class="data row6 col2" >3.000000</td>
#       <td id="T_55c9b_row6_col3" class="data row6 col3" >male</td>
#       <td id="T_55c9b_row6_col4" class="data row6 col4" >2.000000</td>
#       <td id="T_55c9b_row6_col5" class="data row6 col5" >3.000000</td>
#       <td id="T_55c9b_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_55c9b_row6_col7" class="data row6 col7" >21.075000</td>
#       <td id="T_55c9b_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_55c9b_row6_col9" class="data row6 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55c9b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_55c9b_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_55c9b_row7_col2" class="data row7 col2" >3.000000</td>
#       <td id="T_55c9b_row7_col3" class="data row7 col3" >female</td>
#       <td id="T_55c9b_row7_col4" class="data row7 col4" >27.000000</td>
#       <td id="T_55c9b_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_55c9b_row7_col6" class="data row7 col6" >2.000000</td>
#       <td id="T_55c9b_row7_col7" class="data row7 col7" >11.133300</td>
#       <td id="T_55c9b_row7_col8" class="data row7 col8" >nan</td>
#       <td id="T_55c9b_row7_col9" class="data row7 col9" >S</td>
#     </tr>
#     <tr>
#       <th id="T_55c9b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55c9b_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_55c9b_row8_col1" class="data row8 col1" >1.000000</td>
#       <td id="T_55c9b_row8_col2" class="data row8 col2" >2.000000</td>
#       <td id="T_55c9b_row8_col3" class="data row8 col3" >female</td>
#       <td id="T_55c9b_row8_col4" class="data row8 col4" >14.000000</td>
#       <td id="T_55c9b_row8_col5" class="data row8 col5" >1.000000</td>
#       <td id="T_55c9b_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_55c9b_row8_col7" class="data row8 col7" >30.070800</td>
#       <td id="T_55c9b_row8_col8" class="data row8 col8" >nan</td>
#       <td id="T_55c9b_row8_col9" class="data row8 col9" >C</td>
#     </tr>
#     <tr>

# %%
df.iloc[:100].to_excel("../data/titanic/modified_dataset.xlsx")

# %%
df = pd.read_excel("../data/titanic/modified_dataset.xlsx")
df_info(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_46fd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46fd3_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_46fd3_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_46fd3_level0_col2" class="col_heading level0 col2" >Survived</th>
#       <th id="T_46fd3_level0_col3" class="col_heading level0 col3" >Pclass</th>
#       <th id="T_46fd3_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_46fd3_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_46fd3_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_46fd3_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_46fd3_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_46fd3_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_46fd3_level0_col10" class="col_heading level0 col10" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46fd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46fd3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_46fd3_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_46fd3_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_46fd3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_46fd3_row0_col4" class="data row0 col4" >female</td>
#       <td id="T_46fd3_row0_col5" class="data row0 col5" >38.000000</td>
#       <td id="T_46fd3_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_46fd3_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_46fd3_row0_col8" class="data row0 col8" >71.283300</td>
#       <td id="T_46fd3_row0_col9" class="data row0 col9" >C85</td>
#       <td id="T_46fd3_row0_col10" class="data row0 col10" >C</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46fd3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_46fd3_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_46fd3_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_46fd3_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_46fd3_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_46fd3_row1_col5" class="data row1 col5" >26.000000</td>
#       <td id="T_46fd3_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_46fd3_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_46fd3_row1_col8" class="data row1 col8" >7.925000</td>
#       <td id="T_46fd3_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_46fd3_row1_col10" class="data row1 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46fd3_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_46fd3_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_46fd3_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_46fd3_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_46fd3_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_46fd3_row2_col5" class="data row2 col5" >35.000000</td>
#       <td id="T_46fd3_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_46fd3_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_46fd3_row2_col8" class="data row2 col8" >53.100000</td>
#       <td id="T_46fd3_row2_col9" class="data row2 col9" >C123</td>
#       <td id="T_46fd3_row2_col10" class="data row2 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46fd3_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_46fd3_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_46fd3_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_46fd3_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_46fd3_row3_col4" class="data row3 col4" >male</td>
#       <td id="T_46fd3_row3_col5" class="data row3 col5" >35.000000</td>
#       <td id="T_46fd3_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_46fd3_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_46fd3_row3_col8" class="data row3 col8" >8.050000</td>
#       <td id="T_46fd3_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_46fd3_row3_col10" class="data row3 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46fd3_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_46fd3_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_46fd3_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_46fd3_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_46fd3_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_46fd3_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_46fd3_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_46fd3_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_46fd3_row4_col8" class="data row4 col8" >8.458300</td>
#       <td id="T_46fd3_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_46fd3_row4_col10" class="data row4 col10" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46fd3_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_46fd3_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_46fd3_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_46fd3_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_46fd3_row5_col4" class="data row5 col4" >male</td>
#       <td id="T_46fd3_row5_col5" class="data row5 col5" >54.000000</td>
#       <td id="T_46fd3_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_46fd3_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_46fd3_row5_col8" class="data row5 col8" >51.862500</td>
#       <td id="T_46fd3_row5_col9" class="data row5 col9" >E46</td>
#       <td id="T_46fd3_row5_col10" class="data row5 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_46fd3_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_46fd3_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_46fd3_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_46fd3_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_46fd3_row6_col4" class="data row6 col4" >male</td>
#       <td id="T_46fd3_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_46fd3_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_46fd3_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_46fd3_row6_col8" class="data row6 col8" >21.075000</td>
#       <td id="T_46fd3_row6_col9" class="data row6 col9" >nan</td>
#       <td id="T_46fd3_row6_col10" class="data row6 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_46fd3_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_46fd3_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_46fd3_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_46fd3_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_46fd3_row7_col4" class="data row7 col4" >female</td>
#       <td id="T_46fd3_row7_col5" class="data row7 col5" >27.000000</td>
#       <td id="T_46fd3_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_46fd3_row7_col7" class="data row7 col7" >2</td>
#       <td id="T_46fd3_row7_col8" class="data row7 col8" >11.133300</td>
#       <td id="T_46fd3_row7_col9" class="data row7 col9" >nan</td>
#       <td id="T_46fd3_row7_col10" class="data row7 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_46fd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_46fd3_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_46fd3_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_46fd3_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_46fd3_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_46fd3_row8_col4" class="data row8 col4" >female</td>

# %%
df.iloc[:100].to_json("../data/titanic/modified_dataset.json")

# %%
df = pd.read_json("../data/titanic/modified_dataset.json")
df_info(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c29f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c29f_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_9c29f_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_9c29f_level0_col2" class="col_heading level0 col2" >Survived</th>
#       <th id="T_9c29f_level0_col3" class="col_heading level0 col3" >Pclass</th>
#       <th id="T_9c29f_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_9c29f_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_9c29f_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_9c29f_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_9c29f_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_9c29f_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_9c29f_level0_col10" class="col_heading level0 col10" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c29f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c29f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9c29f_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_9c29f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9c29f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_9c29f_row0_col4" class="data row0 col4" >female</td>
#       <td id="T_9c29f_row0_col5" class="data row0 col5" >38.000000</td>
#       <td id="T_9c29f_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9c29f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_9c29f_row0_col8" class="data row0 col8" >71.283300</td>
#       <td id="T_9c29f_row0_col9" class="data row0 col9" >C85</td>
#       <td id="T_9c29f_row0_col10" class="data row0 col10" >C</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c29f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9c29f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_9c29f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_9c29f_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_9c29f_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_9c29f_row1_col5" class="data row1 col5" >26.000000</td>
#       <td id="T_9c29f_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_9c29f_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_9c29f_row1_col8" class="data row1 col8" >7.925000</td>
#       <td id="T_9c29f_row1_col9" class="data row1 col9" >None</td>
#       <td id="T_9c29f_row1_col10" class="data row1 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c29f_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9c29f_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_9c29f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_9c29f_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_9c29f_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_9c29f_row2_col5" class="data row2 col5" >35.000000</td>
#       <td id="T_9c29f_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_9c29f_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_9c29f_row2_col8" class="data row2 col8" >53.100000</td>
#       <td id="T_9c29f_row2_col9" class="data row2 col9" >C123</td>
#       <td id="T_9c29f_row2_col10" class="data row2 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c29f_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9c29f_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_9c29f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_9c29f_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_9c29f_row3_col4" class="data row3 col4" >male</td>
#       <td id="T_9c29f_row3_col5" class="data row3 col5" >35.000000</td>
#       <td id="T_9c29f_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_9c29f_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_9c29f_row3_col8" class="data row3 col8" >8.050000</td>
#       <td id="T_9c29f_row3_col9" class="data row3 col9" >None</td>
#       <td id="T_9c29f_row3_col10" class="data row3 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c29f_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_9c29f_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_9c29f_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_9c29f_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_9c29f_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_9c29f_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_9c29f_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_9c29f_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_9c29f_row4_col8" class="data row4 col8" >8.458300</td>
#       <td id="T_9c29f_row4_col9" class="data row4 col9" >None</td>
#       <td id="T_9c29f_row4_col10" class="data row4 col10" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c29f_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_9c29f_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_9c29f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_9c29f_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_9c29f_row5_col4" class="data row5 col4" >male</td>
#       <td id="T_9c29f_row5_col5" class="data row5 col5" >54.000000</td>
#       <td id="T_9c29f_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_9c29f_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_9c29f_row5_col8" class="data row5 col8" >51.862500</td>
#       <td id="T_9c29f_row5_col9" class="data row5 col9" >E46</td>
#       <td id="T_9c29f_row5_col10" class="data row5 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c29f_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_9c29f_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_9c29f_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_9c29f_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_9c29f_row6_col4" class="data row6 col4" >male</td>
#       <td id="T_9c29f_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_9c29f_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_9c29f_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_9c29f_row6_col8" class="data row6 col8" >21.075000</td>
#       <td id="T_9c29f_row6_col9" class="data row6 col9" >None</td>
#       <td id="T_9c29f_row6_col10" class="data row6 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c29f_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_9c29f_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_9c29f_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_9c29f_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_9c29f_row7_col4" class="data row7 col4" >female</td>
#       <td id="T_9c29f_row7_col5" class="data row7 col5" >27.000000</td>
#       <td id="T_9c29f_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_9c29f_row7_col7" class="data row7 col7" >2</td>
#       <td id="T_9c29f_row7_col8" class="data row7 col8" >11.133300</td>
#       <td id="T_9c29f_row7_col9" class="data row7 col9" >None</td>
#       <td id="T_9c29f_row7_col10" class="data row7 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9c29f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c29f_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_9c29f_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_9c29f_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_9c29f_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_9c29f_row8_col4" class="data row8 col4" >female</

# %%
# It is possibly that this fails, if so skip the two cells below
# !conda install --yes pytables
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\Jan\OneDrive\_Coding\UdemyDataScience\3_Pandas\07_Misc.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Jan/OneDrive/_Coding/UdemyDataScience/3_Pandas/07_Misc.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # It is possibly that this fails, if so skip the two cells below
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jan/OneDrive/_Coding/UdemyDataScience/3_Pandas/07_Misc.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().run_line_magic('conda', 'install pytables')
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2454, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2452     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2453 with self.builtin_trap:
# -> 2454     result = fn(*args, **kwargs)
#    2456 # The code below prevents the output from being displayed
#    2457 # when using magics with decorator @output_can_be_silenced
#    2458 # when the last Python token in the expression is a ';'.
#    2459 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
#      25 if not Path(sys.prefix, "conda-meta", "history").exists():
#      26     raise ValueError(
#      27         "The python kernel does not appear to be a conda environment.  "
#      28         "Please use ``%pip install`` instead."
#      29     )
# ---> 30 return func(*args, **kwargs)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:128, in PackagingMagics.conda(self, line)
#     120 @line_magic
#     121 @is_conda_environment
#     122 def conda(self, line):
#     123     """Run the conda package manager within the current kernel.
#     124
#     125     Usage:
#     126       %conda install [pkgs]
#     127     """
# --> 128     conda = _get_conda_like_executable("conda")
#     129     self._run_command(conda, line)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:53, in _get_conda_like_executable(command)
#      50 # Otherwise, attempt to extract the executable from conda history.
#      51 # This applies in any conda environment.
#      52 history = Path(sys.prefix, "conda-meta", "history").read_text(encoding="utf-8")
# ---> 53 match = re.search(
#      54     rf"^#\s*cmd:\s*(?P<command>.*{executable})\s[create|install]",
#      55     history,
#      56     flags=re.MULTILINE,
#      57 )
#      58 if match:
#      59     return match.groupdict()["command"]
#
# File c:\Users\Jan\anaconda3\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# File c:\Users\Jan\anaconda3\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File c:\Users\Jan\anaconda3\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:982, in parse(str, flags, state)
#     979 state.flags = flags
#     980 state.str = str
# --> 982 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     983 p.state.flags = fix_flags(str, p.state.flags)
#     985 if source.next is not None:
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:457, in _parse_sub(source, state, verbose, nested)
#     455 start = source.tell()
#     456 while True:
# --> 457     itemsappend(_parse(source, state, verbose, nested + 1,
#     458                        not nested and not items))
#     459     if not sourcematch("|"):
#     460         break
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:865, in _parse(source, state, verbose, nested, first)
#     862     group = None
#     863 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     864                not (del_flags & SRE_FLAG_VERBOSE))
# --> 865 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     866 if not source.match(")"):
#     867     raise source.error("missing ), unterminated subpattern",
#     868                        source.tell() - start)
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:457, in _parse_sub(source, state, verbose, nested)
#     455 start = source.tell()
#     456 while True:
# --> 457     itemsappend(_parse(source, state, verbose, nested + 1,
#     458                        not nested and not items))
#     459     if not sourcematch("|"):
#     460         break
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:541, in _parse(source, state, verbose, nested, first)
#     538         continue
#     540 if this[0] == "\\":
# --> 541     code = _escape(source, this, state)
#     542     subpatternappend(code)
#     544 elif this not in SPECIAL_CHARS:
#
# File c:\Users\Jan\anaconda3\Lib\re\_parser.py:395, in _escape(source, escape, state)
#     393 escape += source.getwhile(8, HEXDIGITS)
#     394 if len(escape) != 10:
# --> 395     raise source.error("incomplete escape %s" % escape, len(escape))
#     396 c = int(escape[2:], 16)
#     397 chr(c) # raise ValueError for invalid code
#
# error: incomplete escape \U at position 28

# %%
df.iloc[:100].to_hdf(
    "../data/titanic/modified_dataset.h5",
    key="df",
    mode="w",
)
# Out:
# C:\Users\Jan\AppData\Local\Temp\ipykernel_4208\1323911075.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Sex', 'Cabin', 'Embarked'], dtype='object')]
#
#   df.iloc[:100].to_hdf(

# %%
df = pd.read_hdf("../data/titanic/modified_dataset.h5")
df_info(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_99a93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99a93_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_99a93_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_99a93_level0_col2" class="col_heading level0 col2" >Survived</th>
#       <th id="T_99a93_level0_col3" class="col_heading level0 col3" >Pclass</th>
#       <th id="T_99a93_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_99a93_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_99a93_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_99a93_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_99a93_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_99a93_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_99a93_level0_col10" class="col_heading level0 col10" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99a93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99a93_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_99a93_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_99a93_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_99a93_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_99a93_row0_col4" class="data row0 col4" >female</td>
#       <td id="T_99a93_row0_col5" class="data row0 col5" >38.000000</td>
#       <td id="T_99a93_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_99a93_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_99a93_row0_col8" class="data row0 col8" >71.283300</td>
#       <td id="T_99a93_row0_col9" class="data row0 col9" >C85</td>
#       <td id="T_99a93_row0_col10" class="data row0 col10" >C</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99a93_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_99a93_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_99a93_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_99a93_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_99a93_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_99a93_row1_col5" class="data row1 col5" >26.000000</td>
#       <td id="T_99a93_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_99a93_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_99a93_row1_col8" class="data row1 col8" >7.925000</td>
#       <td id="T_99a93_row1_col9" class="data row1 col9" >None</td>
#       <td id="T_99a93_row1_col10" class="data row1 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99a93_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_99a93_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_99a93_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_99a93_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_99a93_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_99a93_row2_col5" class="data row2 col5" >35.000000</td>
#       <td id="T_99a93_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_99a93_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_99a93_row2_col8" class="data row2 col8" >53.100000</td>
#       <td id="T_99a93_row2_col9" class="data row2 col9" >C123</td>
#       <td id="T_99a93_row2_col10" class="data row2 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99a93_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_99a93_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_99a93_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_99a93_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_99a93_row3_col4" class="data row3 col4" >male</td>
#       <td id="T_99a93_row3_col5" class="data row3 col5" >35.000000</td>
#       <td id="T_99a93_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_99a93_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_99a93_row3_col8" class="data row3 col8" >8.050000</td>
#       <td id="T_99a93_row3_col9" class="data row3 col9" >None</td>
#       <td id="T_99a93_row3_col10" class="data row3 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99a93_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_99a93_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_99a93_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_99a93_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_99a93_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_99a93_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_99a93_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_99a93_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_99a93_row4_col8" class="data row4 col8" >8.458300</td>
#       <td id="T_99a93_row4_col9" class="data row4 col9" >None</td>
#       <td id="T_99a93_row4_col10" class="data row4 col10" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99a93_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_99a93_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_99a93_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_99a93_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_99a93_row5_col4" class="data row5 col4" >male</td>
#       <td id="T_99a93_row5_col5" class="data row5 col5" >54.000000</td>
#       <td id="T_99a93_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_99a93_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_99a93_row5_col8" class="data row5 col8" >51.862500</td>
#       <td id="T_99a93_row5_col9" class="data row5 col9" >E46</td>
#       <td id="T_99a93_row5_col10" class="data row5 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99a93_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_99a93_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_99a93_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_99a93_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_99a93_row6_col4" class="data row6 col4" >male</td>
#       <td id="T_99a93_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_99a93_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_99a93_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_99a93_row6_col8" class="data row6 col8" >21.075000</td>
#       <td id="T_99a93_row6_col9" class="data row6 col9" >None</td>
#       <td id="T_99a93_row6_col10" class="data row6 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99a93_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_99a93_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_99a93_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_99a93_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_99a93_row7_col4" class="data row7 col4" >female</td>
#       <td id="T_99a93_row7_col5" class="data row7 col5" >27.000000</td>
#       <td id="T_99a93_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_99a93_row7_col7" class="data row7 col7" >2</td>
#       <td id="T_99a93_row7_col8" class="data row7 col8" >11.133300</td>
#       <td id="T_99a93_row7_col9" class="data row7 col9" >None</td>
#       <td id="T_99a93_row7_col10" class="data row7 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_99a93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99a93_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_99a93_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_99a93_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_99a93_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_99a93_row8_col4" class="data row8 col4" >female</

# %% [markdown]
# ## Useful Methods

# %%
df_info(df.describe())
# Out:
# <style type="text/css">
# </style>
# <table id="T_f40f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f40f9_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_f40f9_level0_col1" class="col_heading level0 col1" >ID</th>
#       <th id="T_f40f9_level0_col2" class="col_heading level0 col2" >Survived</th>
#       <th id="T_f40f9_level0_col3" class="col_heading level0 col3" >Pclass</th>
#       <th id="T_f40f9_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_f40f9_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_f40f9_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_f40f9_level0_col7" class="col_heading level0 col7" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f40f9_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_f40f9_row0_col0" class="data row0 col0" >100.000000</td>
#       <td id="T_f40f9_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_f40f9_row0_col2" class="data row0 col2" >100.000000</td>
#       <td id="T_f40f9_row0_col3" class="data row0 col3" >100.000000</td>
#       <td id="T_f40f9_row0_col4" class="data row0 col4" >78.000000</td>
#       <td id="T_f40f9_row0_col5" class="data row0 col5" >100.000000</td>
#       <td id="T_f40f9_row0_col6" class="data row0 col6" >100.000000</td>
#       <td id="T_f40f9_row0_col7" class="data row0 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_f40f9_row1_col0" class="data row1 col0" >49.500000</td>
#       <td id="T_f40f9_row1_col1" class="data row1 col1" >50.500000</td>
#       <td id="T_f40f9_row1_col2" class="data row1 col2" >0.410000</td>
#       <td id="T_f40f9_row1_col3" class="data row1 col3" >2.400000</td>
#       <td id="T_f40f9_row1_col4" class="data row1 col4" >27.542692</td>
#       <td id="T_f40f9_row1_col5" class="data row1 col5" >0.720000</td>
#       <td id="T_f40f9_row1_col6" class="data row1 col6" >0.440000</td>
#       <td id="T_f40f9_row1_col7" class="data row1 col7" >29.524083</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_f40f9_row2_col0" class="data row2 col0" >29.011492</td>
#       <td id="T_f40f9_row2_col1" class="data row2 col1" >29.011492</td>
#       <td id="T_f40f9_row2_col2" class="data row2 col2" >0.494311</td>
#       <td id="T_f40f9_row2_col3" class="data row2 col3" >0.816497</td>
#       <td id="T_f40f9_row2_col4" class="data row2 col4" >15.266101</td>
#       <td id="T_f40f9_row2_col5" class="data row2 col5" >1.181336</td>
#       <td id="T_f40f9_row2_col6" class="data row2 col6" >0.967346</td>
#       <td id="T_f40f9_row2_col7" class="data row2 col7" >40.969411</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_f40f9_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_f40f9_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_f40f9_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_f40f9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f40f9_row3_col4" class="data row3 col4" >0.830000</td>
#       <td id="T_f40f9_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_f40f9_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_f40f9_row3_col7" class="data row3 col7" >7.225000</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_f40f9_row4_col0" class="data row4 col0" >24.750000</td>
#       <td id="T_f40f9_row4_col1" class="data row4 col1" >25.750000</td>
#       <td id="T_f40f9_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_f40f9_row4_col3" class="data row4 col3" >2.000000</td>
#       <td id="T_f40f9_row4_col4" class="data row4 col4" >18.250000</td>
#       <td id="T_f40f9_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_f40f9_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_f40f9_row4_col7" class="data row4 col7" >8.050000</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_f40f9_row5_col0" class="data row5 col0" >49.500000</td>
#       <td id="T_f40f9_row5_col1" class="data row5 col1" >50.500000</td>
#       <td id="T_f40f9_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_f40f9_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_f40f9_row5_col4" class="data row5 col4" >26.500000</td>
#       <td id="T_f40f9_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_f40f9_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_f40f9_row5_col7" class="data row5 col7" >15.675000</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_f40f9_row6_col0" class="data row6 col0" >74.250000</td>
#       <td id="T_f40f9_row6_col1" class="data row6 col1" >75.250000</td>
#       <td id="T_f40f9_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_f40f9_row6_col3" class="data row6 col3" >3.000000</td>
#       <td id="T_f40f9_row6_col4" class="data row6 col4" >34.750000</td>
#       <td id="T_f40f9_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_f40f9_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_f40f9_row6_col7" class="data row6 col7" >32.134375</td>
#     </tr>
#     <tr>
#       <th id="T_f40f9_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_f40f9_row7_col0" class="data row7 col0" >99.000000</td>
#       <td id="T_f40f9_row7_col1" class="data row7 col1" >100.000000</td>
#       <td id="T_f40f9_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_f40f9_row7_col3" class="data row7 col3" >3.000000</td>
#       <td id="T_f40f9_row7_col4" class="data row7 col4" >71.000000</td>
#       <td id="T_f40f9_row7_col5" class="data row7 col5" >5.000000</td>
#       <td id="T_f40f9_row7_col6" class="data row7 col6" >5.000000</td>
#       <td id="T_f40f9_row7_col7" class="data row7 col7" >263.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.agg(["min", "max", "median", "mean", "var", "std"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\nanops.py:786, in nanmedian(values, axis, skipna, mask)
#     785 try:
# --> 786     values = values.astype("f8")
#     787 except ValueError as err:
#     788     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'female'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Jan\OneDrive\_Coding\UdemyDataScience\3_Pandas\07_Misc.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jan/OneDrive/_Coding/UdemyDataScience/3_Pandas/07_Misc.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df.agg(["min", "max", "median", "mean", "var", "std"])
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\frame.py:9196, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9193 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9195 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196 result = op.agg()
#    9198 if relabeling:
#    9199     # This is to keep the order to columns occurrence unchanged, and also
#    9200     # keep the order of new columns occurrence unchanged
#    9201
#    9202     # For the return values of reconstruct_func, if relabeling is
#    9203     # False, columns and order will be None.
#    9204     assert columns is not None
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:690, in FrameApply.agg(self)
#     688 result = None
#     689 try:
# --> 690     result = super().agg()
#     691 finally:
#     692     self.obj = obj
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:166, in Apply.agg(self)
#     163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
# --> 166     return self.agg_list_like()
#     168 if callable(arg):
#     169     f = com.get_cython_func(arg)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:351, in Apply.agg_list_like(self)
#     349 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     350 if isinstance(colg, (ABCSeries, ABCDataFrame)):
# --> 351     new_res = colg.aggregate(
#     352         arg, self.axis, *self.args, **self.kwargs
#     353     )
#     354 else:
#     355     new_res = colg.aggregate(arg, *self.args, **self.kwargs)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\series.py:4463, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4460     func = dict(kwargs.items())
#    4462 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4463 result = op.agg()
#    4464 return result
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:1028, in SeriesApply.agg(self)
#    1027 def agg(self):
# -> 1028     result = super().agg()
#    1029     if result is None:
#    1030         f = self.f
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:166, in Apply.agg(self)
#     163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
# --> 166     return self.agg_list_like()
#     168 if callable(arg):
#     169     f = com.get_cython_func(arg)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:335, in Apply.agg_list_like(self)
#     333 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     334 if isinstance(colg, (ABCSeries, ABCDataFrame)):
# --> 335     new_res = colg.aggregate(
#     336         a, self.axis, *self.args, **self.kwargs
#     337     )
#     338 else:
#     339     new_res = colg.aggregate(a, *self.args, **self.kwargs)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\series.py:4463, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4460     func = dict(kwargs.items())
#    4462 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4463 result = op.agg()
#    4464 return result
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:1028, in SeriesApply.agg(self)
#    1027 def agg(self):
# -> 1028     result = super().agg()
#    1029     if result is None:
#    1030         f = self.f
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\generic.py:11623, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, numeric_only, **kwargs)
#   11606 @doc(
#   11607     _num_doc,
#   11608     desc="Return the median of the values over the requested axis.",
#    (...)
#   11621     **kwargs,
#   11622 ):
# > 11623     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\generic.py:11212, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11205 def median(
#   11206     self,
#   11207     axis: Axis | None = 0,
#    (...)
#   11210     **kwargs,
#   11211 ) -> Series | float:
# > 11212     return self._stat_function(
#   11213         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11214     )
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File c:\Users\Jan\anaconda3\Lib\site-packages\pandas\core\nanops.py:789, in nanmedian(values, axis, skipna, mask)
#     786         values = values.astype("f8")
#     787     except ValueError as err:
#     788         # e.g. "could not convert string to float: 'a'"
# --> 789         raise TypeError(str(err)) from err
#     790 if mask is not None:
#     791     values[mask] = np.nan
#
# TypeError: could not convert string to float: 'female'

# %%
print(df["Survived"].value_counts())
# Out:
# 0    59
# 1    41
# Name: Survived, dtype: int64
